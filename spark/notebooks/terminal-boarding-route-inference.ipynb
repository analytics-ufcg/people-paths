# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read Enhanced BUSTE data

# %%
enhanced_buste = pd.read_csv('/local/tarciso/masters/data/bus_trips/test/enhanced-buste/2017_05_01.csv', dtype = {'route': str, 'lineName': str, 'gender': 'category', 'birthdate': str}, parse_dates=['boarding_datetime','gps_datetime'])

# %%
enhanced_buste.sort_values(['cardNum','boarding_datetime']).head(20)
# Out:
#      cardNum   boarding_datetime route busCode  tripNum        gps_datetime  \
# 0   269440.0 2017-05-01 12:21:27   000   09005      NaN                 NaT
# 1   304096.0 2017-05-01 15:55:06   000   06061      NaN                 NaT
# 2   304148.0 2017-05-01 09:55:14   000   03001      NaN                 NaT
# 3   304148.0 2017-05-01 09:55:18   000   03001      NaN                 NaT
# 4   305823.0 2017-05-01 10:21:36   000   09024      NaN                 NaT
# 5   312591.0 2017-05-01 22:19:40   160   BC010     12.0 2017-05-01 22:19:26
# 6   313781.0 2017-05-01 22:45:50   000   02027      NaN                 NaT
# 7   316373.0 2017-05-01 05:44:08   000   00010      NaN                 NaT
# 8   316606.0 2017-05-01 09:13:11   000   03037      NaN                 NaT
# 9   316606.0 2017-05-01 17:38:27   650   HR410      9.0 2017-05-01 17:37:35
# 10  321508.0 2017-05-01 08:04:14   901   MC491      4.0 2017-05-01 08:03:52
# 11  321508.0 2017-05-01 14:58:59   000   08056      NaN                 NaT
# 12  322132.0 2017-05-01 13:30:44   684   HA002      5.0 2017-05-01 13:29:57
# 13  322519.0 2017-05-01 06:51:37   021   GR122      1.0 2017-05-01 06:50:44
# 14  323657.0 2017-05-01 11:36:55   040   HB604      3.0 2017-05-01 11:35:59
# 15  323657.0 2017-05-01 11:36:58   040   HB604      3.0 2017-05-01 11:35:59
# 16  323896.0 2017-05-01 19:47:57   000   05007      NaN                 NaT
# 17  324934.0 2017-05-01 11:52:09   761   JC853      6.0 2017-05-01 11:51:50
# 18  324934.0 2017-05-01 12:10:44   266   BN612      8.0 2017-05-01 12:09:13
# 19  324934.0 2017-05-01 18:47:36   265   HN606     10.0 2017-05-01 18:47:27
#
#     stopPointId   stop_lat   stop_lon  parent_station  shapeId  shapeSequence  \
# 0         14515 -25.483724 -49.350160             NaN      NaN            NaN
# 1         14553 -25.437655 -49.266632             NaN      NaN            NaN
# 2         14494 -25.512487 -49.295048             NaN      NaN            NaN
# 3         14494 -25.512487 -49.295048             NaN      NaN            NaN
# 4         26113 -25.472613 -49.294477             NaN      NaN            NaN
# 5         33069 -25.418018 -49.290745             NaN   1727.0      4870254.0
# 6         25427 -25.433658 -49.263464             NaN      NaN            NaN
# 7         14492 -25.534177 -49.267780             NaN      NaN            NaN
# 8         26105 -25.448327 -49.287780             NaN      NaN            NaN
# 9         36308 -25.564289 -49.338920             NaN   4166.0      6543286.0
# 10        26720 -25.429152 -49.276481             NaN   2899.0      6191389.0
# 11        41767 -25.431351 -49.278868             NaN      NaN            NaN
# 12        38519 -25.564788 -49.315151             NaN   2148.0      6636589.0
# 13        33062 -25.439270 -49.310250             NaN   3269.0      5234186.0
# 14        34134 -25.458001 -49.347135             NaN   1717.0      3366897.0
# 15        34134 -25.458001 -49.347135             NaN   1717.0      3366897.0
# 16        14517 -25.377432 -49.262446             NaN      NaN            NaN
# 17        32097 -25.446517 -49.275789             NaN   2189.0      4293101.0
# 18        26364 -25.428657 -49.270628             NaN   1826.0      6221026.0
# 19        30598 -25.397790 -49.258830             NaN   2796.0      6414509.0
#
#      shapeLat   shapeLon  distanceTraveledShape     problem  \
# 0         NaN        NaN                    NaN         NaN
# 1         NaN        NaN                    NaN         NaN
# 2         NaN        NaN                    NaN         NaN
# 3         NaN        NaN                    NaN         NaN
# 4         NaN        NaN                    NaN         NaN
# 5  -25.418288 -49.290766               3138.401  NO_PROBLEM
# 6         NaN        NaN                    NaN         NaN
# 7         NaN        NaN                    NaN         NaN
# 8         NaN        NaN                    NaN         NaN
# 9  -25.564290 -49.338947               2331.529  NO_PROBLEM
# 10 -25.429056 -49.276093                327.360  NO_PROBLEM
# 11        NaN        NaN                    NaN         NaN
# 12 -25.564733 -49.315162               6982.692  NO_PROBLEM
# 13 -25.439058 -49.310337              28936.900  NO_PROBLEM
# 14 -25.457942 -49.347090               9918.823  NO_PROBLEM
# 15 -25.457942 -49.347090               9918.823  NO_PROBLEM
# 16        NaN        NaN                    NaN         NaN
# 17 -25.446513 -49.275991               8778.214     BETWEEN
# 18 -25.428630 -49.270600               7137.307  NO_PROBLEM
# 19 -25.397652 -49.258705                774.305     BETWEEN
#
#                 lineName birthdate gender
# 0           OPER S/LINHA  20/02/90      M
# 1           OPER S/LINHA  08/07/64      F
# 2           OPER S/LINHA  24/05/72      F
# 3           OPER S/LINHA  24/05/72      F
# 4           OPER S/LINHA  15/07/72      M
# 5       J.MERCES/GUANABA  08/07/61     M
# 6           OPER S/LINHA  12/04/80      M
# 7           OPER S/LINHA  07/06/76      M
# 8           OPER S/LINHA  11/12/59      F
# 9   STA.RITA/PINHEIRINHO  11/12/59     F
# 10       STA. FELICIDADE  18/06/77     F
# 11          OPER S/LINHA  18/06/77      F
# 12       OP. CONTIGENCIA  07/04/74     M
# 13      INTERB II ANTI H  18/10/55     M
# 14       INTERBAIRROS IV  25/01/74     M
# 15       INTERBAIRROS IV  25/01/74     M
# 16          OPER S/LINHA  16/03/60      M
# 17       OP. CONTIGENCIA  23/04/81     F
# 18           ESTRIBO AHÚ  23/04/81     F
# 19       AHÚ/LOS ANGELES  23/04/81     F

# %%
enhanced_buste.dtypes
# Out:
# cardNum                         float64
# boarding_datetime        datetime64[ns]
# route                            object
# busCode                          object
# tripNum                         float64
# gps_datetime             datetime64[ns]
# stopPointId                       int64
# stop_lat                        float64
# stop_lon                        float64
# parent_station                  float64
# shapeId                         float64
# shapeSequence                   float64
# shapeLat                        float64
# shapeLon                        float64
# distanceTraveledShape           float64
# problem                          object
# lineName                         object
# birthdate                        object
# gender                         category
# dtype: object

# %%
trips_per_user = enhanced_buste.groupby(['cardNum']).cardNum.count().reset_index(name='num_trips').num_trips.value_counts(normalize=True) \
                    .reset_index(name='num_trips', level=0)

# %%
trips_per_user
# Out:
#     index  num_trips
# 0       1   0.495213
# 1       2   0.353943
# 2       3   0.077575
# 3       4   0.053353
# 4       6   0.008641
# 5       5   0.007132
# 6       8   0.001564
# 7       7   0.001481
# 8      10   0.000576
# 9       9   0.000439
# 10     11   0.000055
# 11     12   0.000027

# %%
sns.barplot(x='index', y='num_trips', data=trips_per_user)

# %%
enhanced_buste.sort_values(['cardNum','boarding_datetime']).head()
# Out:
#     cardNum   boarding_datetime route busCode  tripNum gps_datetime  \
# 0  269440.0 2017-05-01 12:21:27   000   09005      NaN          NaT
# 1  304096.0 2017-05-01 15:55:06   000   06061      NaN          NaT
# 2  304148.0 2017-05-01 09:55:14   000   03001      NaN          NaT
# 3  304148.0 2017-05-01 09:55:18   000   03001      NaN          NaT
# 4  305823.0 2017-05-01 10:21:36   000   09024      NaN          NaT
#
#    stopPointId   stop_lat   stop_lon  parent_station  shapeId  shapeSequence  \
# 0        14515 -25.483724 -49.350160             NaN      NaN            NaN
# 1        14553 -25.437655 -49.266632             NaN      NaN            NaN
# 2        14494 -25.512487 -49.295048             NaN      NaN            NaN
# 3        14494 -25.512487 -49.295048             NaN      NaN            NaN
# 4        26113 -25.472613 -49.294477             NaN      NaN            NaN
#
#    shapeLat  shapeLon  distanceTraveledShape problem      lineName birthdate  \
# 0       NaN       NaN                    NaN     NaN  OPER S/LINHA  20/02/90
# 1       NaN       NaN                    NaN     NaN  OPER S/LINHA  08/07/64
# 2       NaN       NaN                    NaN     NaN  OPER S/LINHA  24/05/72
# 3       NaN       NaN                    NaN     NaN  OPER S/LINHA  24/05/72
# 4       NaN       NaN                    NaN     NaN  OPER S/LINHA  15/07/72
#
#   gender
# 0      M
# 1      F
# 2      F
# 3      F
# 4      M

# %%
enhanced_buste[(enhanced_buste['stopPointId'] == 14515) & (pd.notnull(enhanced_buste['gps_datetime']))]
# Out:
# Empty DataFrame
# Columns: [cardNum, boarding_datetime, route, busCode, tripNum, gps_datetime, stopPointId, stop_lat, stop_lon, parent_station, shapeId, shapeSequence, shapeLat, shapeLon, distanceTraveledShape, problem, lineName, birthdate, gender]
# Index: []

# %%
enhanced_buste[pd.notnull(enhanced_buste['parent_station'])].head(10)
# Out:
#       cardNum   boarding_datetime route busCode  tripNum        gps_datetime  \
# 117  392810.0 2017-05-01 16:01:56   020   BB613      5.0 2017-05-01 15:38:10
# 132  397471.0 2017-05-01 14:49:41   335   DA011     12.0 2017-05-01 14:41:14
# 186  441343.0 2017-05-01 18:36:58   050   JB301      8.0 2017-05-01 18:36:47
# 317  617197.0 2017-05-01 17:27:40   040   LB300      1.0 2017-05-01 17:27:29
# 326  621108.0 2017-05-01 13:44:13   020   HB300      2.0 2017-05-01 13:37:19
# 34        26631 -25.440706 -49.271456             NaN   2121.0      3919227.0
# 35        26631 -25.440706 -49.271456             NaN   2121.0      3919227.0
# 36        14492 -25.534177 -49.267780             NaN      NaN            NaN
# 37        41775 -25.430012 -49.267614             NaN      NaN            NaN
# 38        14510 -25.400933 -49.330279             NaN      NaN            NaN
# 39        43723 -25.433715 -49.270258             NaN      NaN            NaN
# 40        41751 -25.441058 -49.342500             NaN      NaN            NaN
# 41        14553 -25.437655 -49.266632             NaN      NaN            NaN
# 42        41791 -25.431951 -49.296491             NaN      NaN            NaN
# 43        41791 -25.431951 -49.296491             NaN      NaN            NaN
# 44        30103 -25.475400 -49.201390             NaN   1870.0      5841246.0
# 45        26108 -25.452318 -49.287924             NaN      NaN            NaN
# 46        29013 -25.395154 -49.230623             NaN   1795.0      6595988.0
# 47        14553 -25.437655 -49.266632             NaN      NaN            NaN
# 48        36064 -25.524216 -49.269415             NaN   2051.0      6451304.0
# 49        33035 -25.481840 -49.249370             NaN   2746.0      5846211.0
#
#      shapeLat   shapeLon  distanceTraveledShape     problem  \
# 0         NaN        NaN                    NaN         NaN
# 1         NaN        NaN                    NaN         NaN
# 2         NaN        NaN                    NaN         NaN
# 3         NaN        NaN                    NaN         NaN
# 4         NaN        NaN                    NaN         NaN
# 5  -25.418288 -49.290766               3138.401  NO_PROBLEM
# 6         NaN        NaN                    NaN         NaN
# 7         NaN        NaN                    NaN         NaN
# 8         NaN        NaN                    NaN         NaN
# 9  -25.564290 -49.338947               2331.529  NO_PROBLEM
# 10 -25.429056 -49.276093                327.360  NO_PROBLEM
# 11        NaN        NaN                    NaN         NaN
# 12 -25.564733 -49.315162               6982.692  NO_PROBLEM
# 13 -25.439058 -49.310337              28936.900  NO_PROBLEM
# 14 -25.457942 -49.347090               9918.823  NO_PROBLEM
# 15 -25.457942 -49.347090               9918.823  NO_PROBLEM
# 16        NaN        NaN                    NaN         NaN
# 17 -25.446513 -49.275991               8778.214     BETWEEN
# 18 -25.428630 -49.270600               7137.307  NO_PROBLEM
# 19 -25.397652 -49.258705                774.305     BETWEEN
# 20 -25.397652 -49.258705                774.305     BETWEEN
# 21 -25.377119 -49.243461                943.971  NO_PROBLEM
# 22 -25.423452 -49.269957              10737.357  NO_PROBLEM
# 23 -25.420432 -49.323962               5197.628  NO_PROBLEM
# 24        NaN        NaN                    NaN         NaN
# 25        NaN        NaN                    NaN         NaN
# 26 -25.483120 -49.252633               5923.161     BETWEEN
# 27        NaN        NaN                    NaN         NaN
# 28        NaN        NaN                    NaN         NaN
# 29        NaN        NaN                    NaN         NaN
# 30        NaN        NaN                    NaN         NaN
# 31        NaN        NaN                    NaN         NaN
# 32 -25.437352 -49.240533               7631.732  NO_PROBLEM
# 33 -25.474982 -49.275197               2849.783  NO_PROBLEM
# 34 -25.440753 -49.271511               8174.371  NO_PROBLEM
# 35 -25.440753 -49.271511               8174.371  NO_PROBLEM
# 36        NaN        NaN                    NaN         NaN
# 37        NaN        NaN                    NaN         NaN
# 38        NaN        NaN                    NaN         NaN
# 39        NaN        NaN                    NaN         NaN
# 40        NaN        NaN                    NaN         NaN
# 41        NaN        NaN                    NaN         NaN
# 42        NaN        NaN                    NaN         NaN
# 43        NaN        NaN                    NaN         NaN
# 44 -25.475370 -49.201507              11130.870     BETWEEN
# 45        NaN        NaN                    NaN         NaN
# 46 -25.395122 -49.230490               5892.343  NO_PROBLEM
# 47        NaN        NaN                    NaN         NaN
# 48 -25.524312 -49.269255               6305.294  NO_PROBLEM
# 49 -25.481691 -49.249221               5382.799     BETWEEN
#
#                 lineName birthdate gender
# 0           OPER S/LINHA  20/02/90      M
# 1           OPER S/LINHA  08/07/64      F
# 2           OPER S/LINHA  24/05/72      F
# 3           OPER S/LINHA  24/05/72      F
# 4           OPER S/LINHA  15/07/72      M
# 5       J.MERCES/GUANABA  08/07/61     M
# 6           OPER S/LINHA  12/04/80      M
# 7           OPER S/LINHA  07/06/76      M
# 8           OPER S/LINHA  11/12/59      F
# 9   STA.RITA/PINHEIRINHO  11/12/59     F
# 10       STA. FELICIDADE  18/06/77     F
# 11          OPER S/LINHA  18/06/77      F
# 12       OP. CONTIGENCIA  07/04/74     M
# 13      INTERB II ANTI H  18/10/55     M
# 14       INTERBAIRROS IV  25/01/74     M
# 15       INTERBAIRROS IV  25/01/74     M
# 16          OPER S/LINHA  16/03/60      M
# 17       OP. CONTIGENCIA  23/04/81     F
# 18           ESTRIBO AHÚ  23/04/81     F
# 19       AHÚ/LOS ANGELES  23/04/81     F
# 20       AHÚ/LOS ANGELES  23/04/81     F
# 21           LARANJEIRAS  13/06/56     M
# 22      FERNANDO NORONHA  13/06/56     M
# 23                SAVÓIA  02/02/82     F
# 24      INTERB II ANTI H  01/09/78      F
# 25          OPER S/LINHA  26/01/77      F
# 26      INTERB II ANTI H  01/06/54     M
# 27          OPER S/LINHA  16/04/55      F
# 28          OPER S/LINHA  15/08/73      F
# 29          OPER S/LINHA  09/12/48      M
# 30          OPER S/LINHA  09/12/48      M
# 31          OPER S/LINHA  09/12/48      M
# 32       CABRAL / PORTÃO  20/01/83     F
# 33       OP. CONTIGENCIA  31/05/63     F
# 34       OP. CONTIGENCIA  31/05/63     F
# 35       OP. CONTIGENCIA  31/05/63     F
# 36          OPER S/LINHA  04/06/82      F
# 37          OPER S/LINHA  03/01/73      M
# 38          OPER S/LINHA  25/08/73      F
# 39          OPER S/LINHA  25/08/73      F
# 40      INTERB II ANTI H  09/07/69      F
# 41          OPER S/LINHA  09/07/69      F
# 42      INTERB II ANTI H  11/06/71      F
# 43      INTERB II ANTI H  14/10/72      M
# 44      CENTENÁRIO/HAUER  14/10/72     M
# 45          OPER S/LINHA  03/03/56      F
# 46          V. ESPERANÇA  22/11/83     M
# 47          OPER S/LINHA  22/11/83      M
# 48       OP. CONTIGENCIA  17/12/86     F
# 49         SÃO FRANCISCO  17/12/86     F

# %%
candidate_vehicles = enhanced_buste[(enhanced_buste['parent_station'] == enhanced_buste['stopPointId'].iloc[8]) & 
                               ((pd.to_datetime(enhanced_buste['gps_datetime']) > (pd.to_datetime(enhanced_buste['boarding_datetime'].iloc[8]) - pd.Timedelta(value=5,unit='m'))) & 
                                (pd.to_datetime(enhanced_buste['gps_datetime']) < (pd.to_datetime(enhanced_buste['boarding_datetime'].iloc[8]) + pd.Timedelta(value=20,unit='m'))))]

# %%
candidate_vehicles
# Out:
#         cardNum boarding_datetime route busCode  tripNum        gps_datetime  \
# 112368      NaN               NaT   203   BD138      1.0 2017-05-01 09:16:17
# 114415      NaN               NaT   203   BD147      2.0 2017-05-01 09:26:48
# 232947      NaN               NaT   603   HD249      3.0 2017-05-01 09:14:53
# 233467      NaN               NaT   603   HD250      2.0 2017-05-01 09:33:05
#
#         stopPointId   stop_lat   stop_lon  parent_station  shapeId  \
# 112368        25732 -25.448323 -49.287777         26105.0   3855.0
# 114415        25732 -25.448323 -49.287777         26105.0   3855.0
# 232947        25732 -25.448323 -49.287777         26105.0   3156.0
# 233467        25732 -25.448323 -49.287777         26105.0   3156.0
#
#         shapeSequence   shapeLat   shapeLon  distanceTraveledShape  \
# 112368      4649347.0 -25.448370 -49.287847               5065.989
# 114415      4649347.0 -25.448370 -49.287847               5065.989
# 232947      3758012.0 -25.448258 -49.287815               7432.708
# 233467      3758012.0 -25.448258 -49.287815               7432.708
#
#            problem lineName birthdate gender
# 112368  NO_PROBLEM      NaN       NaN    NaN
# 114415  NO_PROBLEM      NaN       NaN    NaN
# 232947  NO_PROBLEM      NaN       NaN    NaN
# 233467     BETWEEN      NaN       NaN    NaN

# %%
def find_candidate_vehicles(row,gps_df,lower_time_thresh = 0, higher_time_thresh = 40):
    return gps_df[(gps_df['parent_station'] == row['stopPointId']) & 
                               ((pd.to_datetime(gps_df['gps_datetime']) > (pd.to_datetime(row['boarding_datetime']) - pd.Timedelta(value=lower_time_thresh,unit='m'))) & 
                                (pd.to_datetime(gps_df['gps_datetime']) < (pd.to_datetime(row['boarding_datetime']) + pd.Timedelta(value=higher_time_thresh,unit='m'))))]

# %%
first_boarding = 40
second_boarding = 41

# %%
test_data = enhanced_buste.loc[first_boarding:second_boarding].head(1)

# %%
test_data
# Out:
#      cardNum   boarding_datetime route busCode  tripNum gps_datetime  \
# 40  341036.0 2017-05-01 08:57:07   021   08025      NaN          NaT
#
#     stopPointId   stop_lat  stop_lon  parent_station  shapeId  shapeSequence  \
# 40        41751 -25.441058  -49.3425             NaN      NaN            NaN
#
#     shapeLat  shapeLon  distanceTraveledShape problem          lineName  \
# 40       NaN       NaN                    NaN     NaN  INTERB II ANTI H
#
#    birthdate gender
# 40  09/07/69      F

# %%
nstop_lat = enhanced_buste['stop_lat'].loc[second_boarding]
nstop_lon = enhanced_buste['stop_lon'].loc[second_boarding]

# %%
nstop_lat, nstop_lon
# Out:
# (-25.4376552204, -49.266631957100003)

# %%
def dist(stop_lat, stop_lon,next_o_lat,next_o_lon):
    return np.arccos(
        np.sin(np.radians(stop_lat)) * np.sin(np.radians(next_o_lat)) + 
        np.cos(np.radians(stop_lat)) * np.cos(np.radians(next_o_lat)) * 
            np.cos(np.radians(stop_lon) - np.radians(next_o_lon))
    ) * 6371

# %%
dist(-7.213345, -35.907678, -7.219092, -35.877251)
# Out:
# 3.4168198120895932

# %%
def is_vehicle_suitable(row,gps_df,next_stop_lat,next_stop_lon,higher_time_thresh=2):
    vehicle_trip = gps_df[(gps_df['busCode'] == row['busCode']) & (gps_df['tripNum'] == row['tripNum'])].sort_values('gps_datetime')
    vehicle_suitability = vehicle_trip[(vehicle_trip['gps_datetime'] > row['gps_datetime'])].apply(lambda row: dist(row['stop_lat'],row['stop_lon'],next_stop_lat,next_stop_lon), axis=1) \
                            .reset_index(name='dist')
    #print vehicle_suitability['dist']
    return len(vehicle_suitability[vehicle_suitability['dist'] <= 1.0]) > 0

# %%
for index, row in test_data.iterrows():
    cand_vehicles = find_candidate_vehicles(row,enhanced_buste)
    suitable_candidates = []
    for cand_index, cand_row in cand_vehicles.iterrows():
        if (is_vehicle_suitable(cand_row,enhanced_buste,nstop_lat, nstop_lon)):
            suitable_candidates.append(cand_row)
    suitable_candidates_df = pd.DataFrame.from_records(suitable_candidates, columns=cand_vehicles.columns)
    print suitable_candidates_df
    chosen_candidate = suitable_candidates_df.loc[suitable_candidates_df['gps_datetime'].idxmin()]
    print chosen_candidate
# Out:
#    cardNum boarding_datetime route busCode  tripNum        gps_datetime  \
# 0      NaN               NaT   303   DE710      2.0 2017-05-01 09:31:02
# 1      NaN               NaT   303   DE713      2.0 2017-05-01 09:17:39
# 2      NaN               NaT   303   DE719      2.0 2017-05-01 09:05:31
#
#    stopPointId   stop_lat   stop_lon  parent_station  shapeId  shapeSequence  \
# 0        25748 -25.441061 -49.342507         41751.0   3617.0      4399768.0
# 1        25748 -25.441061 -49.342507         41751.0   3617.0      4399768.0
# 2        25748 -25.441061 -49.342507         41751.0   3617.0      4399768.0
#
#     shapeLat   shapeLon  distanceTraveledShape     problem  lineName  \
# 0 -25.441017 -49.342554                456.152  NO_PROBLEM       NaN
# 1 -25.441017 -49.342554                456.152  NO_PROBLEM       NaN
# 2 -25.441017 -49.342554                456.152  NO_PROBLEM       NaN
#
#    birthdate  gender
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# cardNum                                  NaN
# boarding_datetime                        NaT
# route                                    303
# busCode                                DE719
# tripNum                                    2
# gps_datetime             2017-05-01 09:05:31
# stopPointId                            25748
# stop_lat                            -25.4411
# stop_lon                            -49.3425
# parent_station                         41751
# shapeId                                 3617
# shapeSequence                    4.39977e+06
# shapeLat                             -25.441
# shapeLon                            -49.3426
# distanceTraveledShape                456.152
# problem                           NO_PROBLEM
# lineName                                 NaN
# birthdate                                NaN
# gender                                   NaN
# Name: 2, dtype: object
