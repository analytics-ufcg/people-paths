# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read Boarding Data

# %%
boarding_data = pd.read_csv('/local/tarciso/masters/data/bus_trips/test/doc1-2017_05_10.csv')

# %%
boarding_data.head()
# Out:
#   CODLINHA         NOMELINHA CODVEICULO  NUMEROCARTAO HORAUTILIZACAO  \
# 0      000      OPER S/LINHA      00070       1353891       11:05:57
# 1      542     BAIRRO NOVO B      GA117       2357837       17:25:14
# 2      000      OPER S/LINHA      09053       2357837       17:57:33
# 3      000      OPER S/LINHA      09053       2357837       17:57:28
# 4      021  INTERB II ANTI H      08046       1937533       20:17:34
#
#   DATAUTILIZACAO DATANASCIMENTO SEXO
# 0       09/05/17       22/11/58    M
# 1       09/05/17       23/03/72    F
# 2       09/05/17       23/03/72    F
# 3       09/05/17       23/03/72    F
# 4       09/05/17       26/01/72    F

# %%
boardings_total = len(boarding_data)
print boardings_total
# Out:
# 320292

# %%
boarding_data.dtypes
# Out:
# CODLINHA          object
# NOMELINHA         object
# CODVEICULO        object
# NUMEROCARTAO       int64
# HORAUTILIZACAO    object
# DATAUTILIZACAO    object
# DATANASCIMENTO    object
# SEXO              object
# dtype: object

# %% [markdown]
# #### Adding datetime column to ticketing dataframe

# %%
boarding_data['boarding_datetime'] = pd.to_datetime(boarding_data['DATAUTILIZACAO'] + ' ' + boarding_data['HORAUTILIZACAO'],format='%d/%m/%y %H:%M:%S')

# %% [markdown]
# ### Read GPS data for the same day

# %%
gps_data = pd.read_csv('/local/tarciso/masters/data/bus_trips/test/buste-version-its-april-2018/2017_05_09.csv', dtype = {'route': str}, na_values='-')

# %%
gps_data.head()
# Out:
#   route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0   500      1.0     4130        6463875 -25.501550 -49.237590
# 1   500      1.0     4130        6463945 -25.481825 -49.246977
# 2   500      1.0     4130        6464041 -25.459174 -49.258160
# 3   500      1.0     4130        6464140 -25.438837 -49.268129
# 4   500      1.0     4130        6464167 -25.433790 -49.270262
#
#    distanceTraveledShape busCode  gpsPointId     gpsLat     ...      \
# 0               2129.862   GE718         NaN        NaN     ...
# 1               4513.260   GE718         NaN -25.481693     ...
# 2               7268.131   GE718         NaN        NaN     ...
# 3               9735.966   GE718         NaN -25.438738     ...
# 4              10543.422   GE718         NaN -25.433916     ...
#
#    distanceToShapePoint  timestamp stopPointId     problem birthdate  \
# 0                   NaN   06:37:02       27472     BETWEEN       NaN
# 1             15.561821   06:42:45       27551  NO_PROBLEM       NaN
# 2                   NaN   06:47:54       25471     BETWEEN       NaN
# 3             12.105323   06:53:44       25515  NO_PROBLEM       NaN
# 4             21.556105   06:58:25       27560  NO_PROBLEM       NaN
#
#   cardTimestamp lineName cardNum  gender        date
# 0           NaN      NaN     NaN     NaN  2017_05_09
# 1           NaN      NaN     NaN     NaN  2017_05_09
# 2           NaN      NaN     NaN     NaN  2017_05_09
# 3           NaN      NaN     NaN     NaN  2017_05_09
# 4           NaN      NaN     NaN     NaN  2017_05_09
#
# [5 rows x 21 columns]

# %%
gps_data.dtypes
# Out:
# route                     object
# tripNum                  float64
# shapeId                    int64
# shapeSequence              int64
# shapeLat                 float64
# shapeLon                 float64
# distanceTraveledShape    float64
# busCode                   object
# gpsPointId               float64
# gpsLat                   float64
# gpsLon                   float64
# distanceToShapePoint     float64
# timestamp                 object
# stopPointId                int64
# problem                   object
# birthdate                 object
# cardTimestamp             object
# lineName                  object
# cardNum                  float64
# gender                    object
# date                      object
# dtype: object

# %%
len(gps_data)
# Out:
# 642639

# %% [markdown]
# #### Add date and datetime to gps dataframe

# %%
gps_data['date'] = gps_data['date'].str.replace('_','-')
gps_data['gps_datetime'] = pd.to_datetime(gps_data['date'] + ' ' + gps_data['timestamp'],format='%Y-%m-%d %H:%M:%S')
gps_data['boarding_datetime'] = pd.to_datetime(gps_data['date'] + ' ' + gps_data['cardTimestamp'],format='%Y-%m-%d %H:%M:%S')
gps_data['date'] = pd.to_datetime(gps_data['date'], format='%Y-%m-%d')

# %%
gps_data[['date','gps_datetime','boarding_datetime']][pd.notnull(gps_data['boarding_datetime'])].head(10)
# Out:
#           date        gps_datetime   boarding_datetime
# 148 2017-05-09 2017-05-09 06:16:34 2017-05-09 06:17:31
# 150 2017-05-09 2017-05-09 06:18:08 2017-05-09 06:19:04
# 151 2017-05-09 2017-05-09 06:18:08 2017-05-09 06:19:00
# 152 2017-05-09 2017-05-09 06:18:08 2017-05-09 06:18:15
# 153 2017-05-09 2017-05-09 06:18:08 2017-05-09 06:18:11
# 154 2017-05-09 2017-05-09 06:19:18 2017-05-09 06:19:34
# 155 2017-05-09 2017-05-09 06:20:46 2017-05-09 06:21:39
# 157 2017-05-09 2017-05-09 06:23:04 2017-05-09 06:23:53
# 158 2017-05-09 2017-05-09 06:23:56 2017-05-09 06:24:41
# 163 2017-05-09 2017-05-09 06:29:02 2017-05-09 06:30:09

# %% [markdown]
# #### Analyzing Boarding and GPS Data

# %%
boarding_data[['NUMEROCARTAO','DATAUTILIZACAO','HORAUTILIZACAO','CODLINHA','CODVEICULO']] \
    .sort_values(['NUMEROCARTAO','DATAUTILIZACAO']).head(10)
# Out:
#         NUMEROCARTAO DATAUTILIZACAO HORAUTILIZACAO CODLINHA CODVEICULO
# 243380        228696       09/05/17       07:01:00      000      08024
# 243381        228696       09/05/17       13:55:35      000      05312
# 61748         229948       09/05/17       06:29:09      654      HA017
# 199680        233641       09/05/17       12:08:17      021      04020
# 199681        233641       09/05/17       06:39:21      000      01026
# 199751        257342       09/05/17       17:24:51      000      01021
# 199752        257342       09/05/17       07:48:58      511      EA172
# 14035         272904       09/05/17       17:24:52      000      03047
# 199772        300327       09/05/17       16:52:22      000      03057
# 199773        300327       09/05/17       06:56:45      OPC      HA240

# %%
gps_data[['cardNum','cardTimestamp','timestamp','route','busCode','tripNum','stopPointId']] \
            .sort_values(['cardNum','cardTimestamp','timestamp']).head(10)
# Out:
#          cardNum cardTimestamp timestamp route busCode  tripNum  stopPointId
# 558392  229948.0      06:29:09  06:28:49   654   HA017      2.0        35350
# 260499  257342.0      07:48:58  07:47:51   511   EA172      4.0        31195
# 408836  300327.0      06:56:45  06:55:54   654   HA240      3.0        36094
# 199446  304127.0      10:24:50  10:22:28   175   BC010      5.0        31748
# 305000  304127.0      10:57:36  10:42:18   370   LC016      3.0         3377
# 517064  304627.0      14:17:23  14:16:09   370   BC032      6.0         3377
# 421546  304627.0      16:24:40  15:45:37   370   LC020      6.0        30303
# 108958  306135.0      07:56:49  07:56:48   777   JC004      3.0        32097
# 258047  310241.0      17:55:48  17:55:42   468   DC090      5.0        30884
# 112368  312500.0      13:26:11  13:24:48   175   BC282      6.0        28632

# %% [markdown]
# ### Checking for problems

# %% [markdown]
# #### Analyzing Trip Start/End times

# %%
trip_initial_time = gps_data[(gps_data['route'] == '654') & (gps_data['busCode'] == 'HA017')].sort_values('timestamp').groupby('tripNum').first() \
    .reset_index() \
    .sort_values(['tripNum','timestamp'])[['tripNum','timestamp']]
    
trip_final_time = gps_data[(gps_data['route'] == '654') & (gps_data['busCode'] == 'HA017')].sort_values('timestamp').groupby('tripNum').last() \
    .reset_index() \
    .sort_values(['tripNum','timestamp'])[['tripNum','timestamp']]

trip_initial_final_time = trip_initial_time.merge(trip_final_time, on='tripNum', how='inner')

trip_initial_final_time
# Out:
#     tripNum timestamp_x timestamp_y
# 0       1.0    05:16:44    05:56:19
# 1       2.0    05:58:50    06:32:01
# 2       3.0    06:36:39    07:19:31
# 3       4.0    07:24:13    08:04:12
# 4       5.0    08:05:18    08:45:37
# 5       6.0    08:50:02    09:37:32
# 6       7.0    09:40:53    10:22:45
# 7       8.0    10:25:55    11:05:00
# 8       9.0    11:09:38    11:57:20
# 9      10.0    12:03:37    12:46:17
# 10     11.0    12:49:47    13:37:43
# 11     12.0    13:39:32    14:22:22
# 12     13.0    14:24:38    15:06:31
# 13     14.0    15:09:31    15:49:31
# 14     15.0    15:54:15    16:41:08
# 15     16.0    16:47:09    17:31:13
# 16     17.0    17:37:02    18:24:12
# 17     18.0    18:25:27    19:10:58
# 18     19.0    19:10:58    19:35:59
# 19     20.0    23:03:15    23:03:15

# %% [markdown]
# #### Analyzing unique boarding-gps matches (there should be no duplicates)

# %%
first_cols = ['cardNum', 'boarding_datetime','gps_datetime','route','busCode','stopPointId']
other_cols = [col for col in gps_data.columns if col not in first_cols]
cols_order = first_cols + other_cols
boarding_key_cols = ['cardNum','boarding_datetime']
gps_by_boarding = gps_data[cols_order] \
    .dropna(subset=boarding_key_cols) \
    .sort_values(boarding_key_cols)
gps_by_boarding.head(20)
# Out:
#          cardNum   boarding_datetime        gps_datetime route busCode  \
# 558392  229948.0 2017-05-09 06:29:09 2017-05-09 06:28:49   654   HA017
# 260499  257342.0 2017-05-09 07:48:58 2017-05-09 07:47:51   511   EA172
# 408836  300327.0 2017-05-09 06:56:45 2017-05-09 06:55:54   654   HA240
# 199446  304127.0 2017-05-09 10:24:50 2017-05-09 10:22:28   175   BC010
# 305000  304127.0 2017-05-09 10:57:36 2017-05-09 10:42:18   370   LC016
# 517064  304627.0 2017-05-09 14:17:23 2017-05-09 14:16:09   370   BC032
# 421546  304627.0 2017-05-09 16:24:40 2017-05-09 15:45:37   370   LC020
# 108958  306135.0 2017-05-09 07:56:49 2017-05-09 07:56:48   777   JC004
# 258047  310241.0 2017-05-09 17:55:48 2017-05-09 17:55:42   468   DC090
# 112368  312500.0 2017-05-09 13:26:11 2017-05-09 13:24:48   175   BC282
# 404554  312823.0 2017-05-09 13:35:49 2017-05-09 13:34:57   652   LA001
# 4889    312823.0 2017-05-09 14:37:15 2017-05-09 14:35:06   901   MC076
# 253440  313992.0 2017-05-09 06:58:00 2017-05-09 06:57:02   372   BC316
# 395015  313992.0 2017-05-09 18:14:02 2017-05-09 18:12:41   372   BC323
# 193989  314156.0 2017-05-09 08:17:37 2017-05-09 08:16:43   673   HN615
# 378850  314357.0 2017-05-09 07:30:43 2017-05-09 07:29:28   534   GA002
# 138294  316234.0 2017-05-09 07:06:26 2017-05-09 07:05:13   777   JC008
# 3483    316552.0 2017-05-09 08:51:29 2017-05-09 08:50:55   216   DR403
# 260699  316588.0 2017-05-09 10:56:21 2017-05-09 10:55:00   511   EA172
# 99618   317896.0 2017-05-09 07:26:08 2017-05-09 07:25:52   542   GA124
#
#         stopPointId  tripNum  shapeId  shapeSequence   shapeLat    ...      \
# 558392        35350      2.0     2953        3848651 -25.492612    ...
# 260499        31195      4.0     2746        5846156 -25.498727    ...
# 408836        36094      3.0     2106        6040871 -25.501307    ...
# 199446        31748      5.0     1743        5444496 -25.450869    ...
# 305000         3377      3.0     3669        6592154 -25.428220    ...
# 517064         3377      6.0     2789        5510110 -25.428214    ...
# 421546        30303      6.0     2789        5510843 -25.455839    ...
# 108958        32097      3.0     2194        4299781 -25.446370    ...
# 258047        30884      5.0     1926        4418132 -25.455683    ...
# 112368        28632      6.0     2743        5404932 -25.431576    ...
# 404554        34977     13.0     2101        3834325 -25.534607    ...
# 4889          29598      9.0     2257        6191372 -25.428454    ...
# 253440        29914      2.0     1891        6136884 -25.427901    ...
# 395015        26336     10.0     1891        6136922 -25.432867    ...
# 193989        32176      3.0     2138        3971672 -25.489119    ...
# 378850        29963      4.0     1977        6377734 -25.524766    ...
# 138294        33632      1.0     2194        4299604 -25.462000    ...
# 3483          29124      1.0     2778        5951693 -25.428777    ...
# 260699        29823      9.0     2746        5846113 -25.507262    ...
# 99618         31256      7.0     1988        6403964 -25.550431    ...
#
#            gpsLat     gpsLon  distanceToShapePoint  timestamp     problem  \
# 558392        NaN        NaN                   NaN   06:28:49     BETWEEN
# 260499 -25.498735 -49.247771              9.667548   07:47:51  NO_PROBLEM
# 408836 -25.501313 -49.319971              0.737270   06:55:54  NO_PROBLEM
# 199446 -25.450986 -49.254015             13.270845   10:22:28  NO_PROBLEM
# 305000 -25.428210 -49.246896              5.426374   10:42:18  NO_PROBLEM
# 517064 -25.428125 -49.246675             18.124441   14:16:09  NO_PROBLEM
# 421546 -25.455803 -49.323013              5.475631   15:45:37  NO_PROBLEM
# 108958 -25.446305 -49.275308             32.238018   07:56:48  NO_PROBLEM
# 258047 -25.455618 -49.241156              8.323350   17:55:42  NO_PROBLEM
# 112368 -25.431573 -49.271680              6.383659   13:24:48  NO_PROBLEM
# 404554 -25.534736 -49.331276             14.430964   13:34:57  NO_PROBLEM
# 4889   -25.428460 -49.272968              1.668976   14:35:06  NO_PROBLEM
# 253440 -25.427925 -49.263270              4.198976   06:57:02  NO_PROBLEM
# 395015 -25.432848 -49.270538              6.924298   18:12:41  NO_PROBLEM
# 193989 -25.489166 -49.306946             10.080134   08:16:43  NO_PROBLEM
# 378850 -25.524736 -49.246725             25.170067   07:29:28  NO_PROBLEM
# 138294 -25.462028 -49.332375              3.564214   07:05:13  NO_PROBLEM
# 3483   -25.428535 -49.249026             28.560526   08:50:55  NO_PROBLEM
# 260699 -25.507065 -49.264153             21.913303   10:55:00  NO_PROBLEM
# 99618  -25.550515 -49.265211             11.738668   07:25:52  NO_PROBLEM
#
#         birthdate cardTimestamp          lineName gender       date
# 558392   28/04/95      06:29:09      CAMPO ALEGRE     F  2017-05-09
# 260499   24/01/71      07:48:58     SÃO FRANCISCO     F  2017-05-09
# 408836   20/05/59      06:56:45   OP. CONTIGENCIA     F  2017-05-09
# 199446   09/06/54      10:24:50  BOM RETIRO / PUC     M  2017-05-09
# 305000   09/06/54      10:57:36  RUA XV / BARIGUI     M  2017-05-09
# 517064   05/04/53      14:17:23  RUA XV / BARIGUI     F  2017-05-09
# 421546   05/04/53      16:24:40  RUA XV / BARIGUI     F  2017-05-09
# 108958   29/10/52      07:56:49          V. VELHA     M  2017-05-09
# 258047   13/01/72      17:55:48       JD. ITIBERÊ     M  2017-05-09
# 112368   26/02/82      13:26:11  BOM RETIRO / PUC     F  2017-05-09
# 404554   03/09/88      13:35:49          V. VERDE     F  2017-05-09
# 4889     03/09/88      14:37:15   STA. FELICIDADE     F  2017-05-09
# 253440   29/07/54      06:58:00            TARUMÃ     M  2017-05-09
# 395015   29/07/54      18:14:02            TARUMÃ     M  2017-05-09
# 193989   10/04/69      08:17:37           FORMOSA     F  2017-05-09
# 378850   28/05/59      07:30:43  PARIGOT DE SOUZA     F  2017-05-09
# 138294   06/01/75      07:06:26          V. VELHA     F  2017-05-09
# 3483     23/09/65      08:51:29   CABRAL / PORTÃO     F  2017-05-09
# 260699   12/05/51      10:56:21     SÃO FRANCISCO     F  2017-05-09
# 99618    16/09/60      07:26:08     BAIRRO NOVO B     F  2017-05-09
#
# [20 rows x 23 columns]
