# %%
import pyspark
from pyspark import SparkContext
from pyspark.sql.window import Window
from pyspark.sql import functions as F
from pyspark.sql import types as T

import json
import numpy as np

# %%
def rename_columns(df, list_of_tuples):
    for (old_col, new_col) in list_of_tuples:
        df = df.withColumnRenamed(old_col, new_col)
    return df

def read_data(sqlContext, filepath):
    df = sqlContext.read.format("com.databricks.spark.csv")\
        .option("header", "true")\
        .option("inferSchema", "true") \
        .option("nullValue", "-")\
        .load(filepath)

    return df

def print_df(df,l=10):
    return df.limit(l).toPandas()

# %% [markdown]
# ### Read Boarding Data

# %%
sc = SparkContext.getOrCreate()
sqlContext = pyspark.SQLContext(sc)

# %%
exp_data_folder_path = '/local/tarciso/masters/experiments/preliminary-exp/preliminary-exp-sample-data/'
boarding_data = read_data(sqlContext,exp_data_folder_path + 'clean_boardings')

# %%
boarding_data.printSchema()
# Out:
# root
#  |-- route: integer (nullable = true)
#  |-- tripNum: integer (nullable = true)
#  |-- shapeId: integer (nullable = true)
#  |-- shapeSequence: integer (nullable = true)
#  |-- shapeLat: double (nullable = true)
#  |-- shapeLon: double (nullable = true)
#  |-- distanceTraveledShape: double (nullable = true)
#  |-- busCode: string (nullable = true)
#  |-- gpsPointId: string (nullable = true)
#  |-- gpsLat: double (nullable = true)
#  |-- gpsLon: double (nullable = true)
#  |-- distanceToShapePoint: double (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- busStopId: integer (nullable = true)
#  |-- problem: string (nullable = true)
#  |-- userBirthdate: string (nullable = true)
#  |-- cardTimestamp: string (nullable = true)
#  |-- lineName: string (nullable = true)
#  |-- cardNum: integer (nullable = true)
#  |-- userGender: string (nullable = true)
#  |-- date: timestamp (nullable = true)

# %%
print_df(boarding_data)
# Out:
#    route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0    386       11     2802        5577654 -25.432806 -49.270301
# 1    633        4     2065        6487165 -25.526466 -49.270083
# 2    901        8     2257        6191372 -25.428454 -49.272983
# 3    547        7     1994        6165297 -25.540439 -49.267179
# 4    216        7     1785        5950904 -25.460560 -49.273292
# 5    630        7     2060        6483927 -25.536582 -49.318214
# 6    535        1     1979        6393361 -25.553457 -49.251038
# 7    614        7     2031        5830806 -25.477055 -49.296942
# 8    650        5     4166        6543269 -25.565282 -49.333792
# 9    703        4     2165        5889283 -25.448696 -49.281666
#
#    distanceTraveledShape busCode gpsPointId     gpsLat    ...      \
# 0               9827.101   BN611       None -25.432878    ...
# 1                550.270   GA212       None -25.526411    ...
# 2               8195.073   MC076       None -25.428393    ...
# 3               4399.381   GA138       None -25.540383    ...
# 4              10413.488   CA600       None -25.460600    ...
# 5               4623.365   HA260       None -25.536581    ...
# 6               1220.197   EA601       None -25.553476    ...
# 7               6993.931   GR405       None -25.477413    ...
# 8               1742.133   HA031       None -25.565225    ...
# 9               9226.879   JC309       None -25.448716    ...
#
#    distanceToShapePoint  timestamp busStopId     problem userBirthdate  \
# 0              8.001811   18:25:34     26342  NO_PROBLEM      20/12/78
# 1             17.169727   07:23:35     36066  NO_PROBLEM      01/07/85
# 2              8.328148   13:40:38     29598  NO_PROBLEM      14/08/80
# 3              6.269928   07:31:54     31269  NO_PROBLEM      11/04/86
# 4              5.880426   17:02:09     29145  NO_PROBLEM      21/10/86
# 5              1.364230   17:17:10     35159  NO_PROBLEM      02/10/76
# 6              4.830964   06:34:54     36874  NO_PROBLEM      05/07/82
# 7             39.898100   19:01:15     31800  NO_PROBLEM      29/06/63
# 8              6.928054   10:07:30     36299  NO_PROBLEM      05/08/85
# 9              9.136992   12:39:17     33480  NO_PROBLEM      27/08/85
#
#   cardTimestamp              lineName  cardNum  userGender       date
# 0      18:27:58                CAJURU   413674           F 2017-05-10
# 1      07:24:25      PARIGOT DE SOUZA   550073           F 2017-05-10
# 2      13:42:41       STA. FELICIDADE   597648           F 2017-05-10
# 3      07:32:28       OP. CONTIGENCIA   623748           F 2017-05-10
# 4      17:02:25       CABRAL / PORTÃO   654450           F 2017-05-10
# 5      17:18:01         VITÓRIA RÉGIA   942814           M 2017-05-10
# 6      06:35:25        OSTERNACK/BOQ.   975700           F 2017-05-10
# 7      19:02:54        FAZENDINHA/PUC  1034205           F 2017-05-10
# 8      10:07:37  STA.RITA/PINHEIRINHO  1049145           F 2017-05-10
# 9      12:39:57                 CAIUÁ  1051414           F 2017-05-10
#
# [10 rows x 21 columns]

# %%
boarding_data = boarding_data.orderBy(['cardNum','cardTimestamp'])
print_df(boarding_data.select(['cardNum','cardTimestamp','route','busCode']), l=20)
# Out:
#     cardNum cardTimestamp  route busCode
# 0    304127      17:02:45    175   BC289
# 1    304127      17:46:02    370   BC032
# 2    313992      06:55:21    372   BC312
# 3    313992      17:09:27     50   LB602
# 4    317896      07:01:40    542   GA124
# 5    317896      17:05:57    216   CA600
# 6    321530      07:50:18    533   EA166
# 7    321530      16:47:25     20   KB605
# 8    321916      05:55:17    779   JC865
# 9    321916      15:02:51    777   JC008
# 10   327178      12:46:13    175   BC018
# 11   327178      16:54:37    175   BC018
# 12   328918      11:55:17    643   GA164
# 13   328918      11:55:20    643   GA164
# 14   331911      08:08:40    370   BC032
# 15   331911      14:54:45    373   CC297
# 16   334290      07:16:10    614   GR403
# 17   334290      17:05:51    703   JC316
# 18   334492      08:28:45    777   LC027
# 19   334492      17:40:55    701   JC604

# %% [markdown]
# ### Analyzing Boarding data

# %%
boarding_data = boarding_data.withColumn('boarding_id',F.monotonically_increasing_id())
print_df(boarding_data)
# Out:
#    route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0    175       10     1743        5444509 -25.451133 -49.252930
# 1    370        9     2789        5510463 -25.432528 -49.272411
# 2    372        2     1891        6136884 -25.427901 -49.263238
# 3     50        6     1719        5305706 -25.452114 -49.223827
# 4    542        6     1988        6403964 -25.550431 -49.265282
# 5    216        7     1785        5950930 -25.466362 -49.279723
# 6    533        3     2872        6247890 -25.516804 -49.230914
# 7     20        6     3260        6011921 -25.447553 -49.225671
# 8    779        1     2904        5602222 -25.459817 -49.319788
# 9    777        8     2194        4299859 -25.435150 -49.273297
#
#    distanceTraveledShape busCode gpsPointId     gpsLat     ...      timestamp  \
# 0               8002.630   BC289       None -25.451213     ...       17:01:16
# 1               3061.094   BC032       None -25.432510     ...       17:45:02
# 2               8989.204   BC312       None -25.427911     ...       06:54:19
# 3              14883.248   LB602       None -25.452128     ...       17:08:39
# 4               3509.356   GA124       None -25.550511     ...       07:01:18
# 5              11325.265   CA600       None -25.466531     ...       17:05:48
# 6               2645.339   EA166       None -25.516953     ...       07:30:20
# 7               1047.327   KB605       None -25.447411     ...       16:44:40
# 8               2787.974   JC865       None -25.459835     ...       05:54:43
# 9               8945.611   JC008       None -25.435151     ...       15:01:33
#
#    busStopId     problem  userBirthdate cardTimestamp          lineName  \
# 0      31749  NO_PROBLEM       09/06/54      17:02:45  BOM RETIRO / PUC
# 1      26355  NO_PROBLEM       09/06/54      17:46:02  RUA XV / BARIGUI
# 2      29914  NO_PROBLEM       29/07/54      06:55:21            TARUMÃ
# 3      14404  NO_PROBLEM       29/07/54      17:09:27    INTERBAIRROS V
# 4      31256  NO_PROBLEM       16/09/60      07:01:40     BAIRRO NOVO B
# 5      29165  NO_PROBLEM       16/09/60      17:05:57   CABRAL / PORTÃO
# 6      30037  NO_PROBLEM       12/06/81      07:50:18   OP. CONTIGENCIA
# 7      32704  NO_PROBLEM       12/06/81      16:47:25   OP. CONTIGENCIA
# 8      33567  NO_PROBLEM       17/11/52      05:55:17  V.VELHA / BURITI
# 9      26149  NO_PROBLEM       17/11/52      15:02:51          V. VELHA
#
#   cardNum userGender       date boarding_id
# 0  304127          M 2017-05-10           0
# 1  304127          M 2017-05-10           1
# 2  313992          M 2017-05-10           2
# 3  313992          M 2017-05-10           3
# 4  317896          F 2017-05-10           4
# 5  317896          F 2017-05-10           5
# 6  321530          F 2017-05-10           6
# 7  321530          F 2017-05-10           7
# 8  321916          F 2017-05-10           8
# 9  321916          F 2017-05-10           9
#
# [10 rows x 22 columns]

# %%
user_boarding_w = Window.partitionBy(boarding_data.cardNum, boarding_data.date).orderBy(boarding_data.cardTimestamp)
od_matrix_ids = boarding_data.select(F.col('cardNum'),
                     F.col('boarding_id'), 
                     F.lead('boarding_id',default=-1).over(user_boarding_w).alias('alighting_id'),
                     F.first('boarding_id',True).over(user_boarding_w).alias('first_boarding'))

print_df(od_matrix_ids)
# Out:
#    cardNum  boarding_id  alighting_id  first_boarding
# 0   634049   8589934649    8589934650      8589934649
# 1   634049   8589934650            -1      8589934649
# 2   740288  17179869242   17179869243     17179869242
# 3   740288  17179869243            -1     17179869242
# 4   824709  25769803915   25769803916     25769803915
# 5   824709  25769803916            -1     25769803915
# 6   825966  25769803919   25769803920     25769803919
# 7   825966  25769803920            -1     25769803919
# 8   938570  42949672981   42949672982     42949672981
# 9   938570  42949672982            -1     42949672981

# %%
od_matrix_ids = od_matrix_ids.withColumn('alighting_id', 
                     F.when(F.col('alighting_id') == -1,F.col('first_boarding')). \
                                         otherwise(F.col('alighting_id'))).drop('first_boarding')

print_df(od_matrix_ids)
# Out:
#    cardNum  boarding_id  alighting_id
# 0   634049   8589934693    8589934694
# 1   634049   8589934694    8589934693
# 2   740288  17179869256   17179869257
# 3   740288  17179869257   17179869256
# 4   824709  25769803888   25769803889
# 5   824709  25769803889   25769803888
# 6   825966  25769803892   25769803893
# 7   825966  25769803893   25769803892
# 8   938570  42949673066   42949673067
# 9   938570  42949673067   42949673066

# %%
boarding_data.printSchema()
# Out:
# root
#  |-- route: integer (nullable = true)
#  |-- tripNum: integer (nullable = true)
#  |-- shapeId: integer (nullable = true)
#  |-- shapeSequence: integer (nullable = true)
#  |-- shapeLat: double (nullable = true)
#  |-- shapeLon: double (nullable = true)
#  |-- distanceTraveledShape: double (nullable = true)
#  |-- busCode: string (nullable = true)
#  |-- gpsPointId: string (nullable = true)
#  |-- gpsLat: double (nullable = true)
#  |-- gpsLon: double (nullable = true)
#  |-- distanceToShapePoint: double (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- busStopId: integer (nullable = true)
#  |-- problem: string (nullable = true)
#  |-- userBirthdate: string (nullable = true)
#  |-- cardTimestamp: string (nullable = true)
#  |-- lineName: string (nullable = true)
#  |-- cardNum: integer (nullable = true)
#  |-- userGender: string (nullable = true)
#  |-- date: timestamp (nullable = true)
#  |-- boarding_id: long (nullable = false)

# %%
origin_matrix = boarding_data.select(F.col("route").alias("o_route"),
                                    F.col("busCode").alias("o_bus_code"),
                                    F.col("date").alias("o_date"),
                                    F.col("tripNum").alias("o_tripNum"),
                                    F.col("cardTimestamp").alias("o_timestamp"),
                                    F.col("shapeId").alias("o_shape_id"),
                                    F.col("shapeSequence").alias("o_shape_seq"),
                                    F.col("shapeLat").alias("o_shape_lat"),
                                    F.col("shapeLon").alias("o_shape_lon"),
                                    F.col("busStopId").alias("o_stop_id"),
                                    F.col("boarding_id").alias("o_boarding_id"))

# %%
dest_matrix = boarding_data.select(F.col("route").alias("d_route"),
                                    F.col("busCode").alias("d_bus_code"),
                                    F.col("date").alias("d_date"),
                                    F.col("tripNum").alias("d_tripNum"),
                                    F.col("cardTimestamp").alias("d_timestamp"),
                                    F.col("shapeId").alias("d_shape_id"),
                                    F.col("shapeSequence").alias("d_shape_seq"),
                                    F.col("shapeLat").alias("d_shape_lat"),
                                    F.col("shapeLon").alias("d_shape_lon"),
                                    F.col("busStopId").alias("d_stop_id"),
                                    F.col("boarding_id").alias("d_boarding_id"))

# %%
print_df(origin_matrix)
# Out:
#    o_route o_bus_code     o_date  o_tripNum o_timestamp  o_shape_id  \
# 0      175      BC289 2017-05-10         10    17:02:45        1743
# 1      370      BC032 2017-05-10          9    17:46:02        2789
# 2      372      BC312 2017-05-10          2    06:55:21        1891
# 3       50      LB602 2017-05-10          6    17:09:27        1719
# 4      542      GA124 2017-05-10          6    07:01:40        1988
# 5      216      CA600 2017-05-10          7    17:05:57        1785
# 6      533      EA166 2017-05-10          3    07:50:18        2872
# 7       20      KB605 2017-05-10          6    16:47:25        3260
# 8      779      JC865 2017-05-10          1    05:55:17        2904
# 9      777      JC008 2017-05-10          8    15:02:51        2194
#
#    o_shape_seq  o_shape_lat  o_shape_lon  o_stop_id  o_boarding_id
# 0      5444509   -25.451133   -49.252930      31749              0
# 1      5510463   -25.432528   -49.272411      26355              1
# 2      6136884   -25.427901   -49.263238      29914              2
# 3      5305706   -25.452114   -49.223827      14404              3
# 4      6403964   -25.550431   -49.265282      31256              4
# 5      5950930   -25.466362   -49.279723      29165              5
# 6      6247890   -25.516804   -49.230914      30037              6
# 7      6011921   -25.447553   -49.225671      32704              7
# 8      5602222   -25.459817   -49.319788      33567              8
# 9      4299859   -25.435150   -49.273297      26149              9

# %%
print_df(dest_matrix)
# Out:
#    d_route d_bus_code     d_date  d_tripNum d_timestamp  d_shape_id  \
# 0      175      BC289 2017-05-10         10    17:02:45        1743
# 1      370      BC032 2017-05-10          9    17:46:02        2789
# 2      372      BC312 2017-05-10          2    06:55:21        1891
# 3       50      LB602 2017-05-10          6    17:09:27        1719
# 4      542      GA124 2017-05-10          6    07:01:40        1988
# 5      216      CA600 2017-05-10          7    17:05:57        1785
# 6      533      EA166 2017-05-10          3    07:50:18        2872
# 7       20      KB605 2017-05-10          6    16:47:25        3260
# 8      779      JC865 2017-05-10          1    05:55:17        2904
# 9      777      JC008 2017-05-10          8    15:02:51        2194
#
#    d_shape_seq  d_shape_lat  d_shape_lon  d_stop_id  d_boarding_id
# 0      5444509   -25.451133   -49.252930      31749              0
# 1      5510463   -25.432528   -49.272411      26355              1
# 2      6136884   -25.427901   -49.263238      29914              2
# 3      5305706   -25.452114   -49.223827      14404              3
# 4      6403964   -25.550431   -49.265282      31256              4
# 5      5950930   -25.466362   -49.279723      29165              5
# 6      6247890   -25.516804   -49.230914      30037              6
# 7      6011921   -25.447553   -49.225671      32704              7
# 8      5602222   -25.459817   -49.319788      33567              8
# 9      4299859   -25.435150   -49.273297      26149              9

# %%
origin_dest_matrix = origin_matrix.join(od_matrix_ids, 
                                        origin_matrix.o_boarding_id == od_matrix_ids.boarding_id, 'inner') \
                                    .join(dest_matrix, od_matrix_ids.alighting_id == dest_matrix.d_boarding_id, 'inner')

# %%
print_df(origin_dest_matrix)
# Out:
#    o_route o_bus_code     o_date  o_tripNum o_timestamp  o_shape_id  \
# 0      175      BC289 2017-05-10         10    17:02:45        1743
# 1      370      BC032 2017-05-10          9    17:46:02        2789
# 2      372      BC312 2017-05-10          2    06:55:21        1891
# 3       50      LB602 2017-05-10          6    17:09:27        1719
# 4      542      GA124 2017-05-10          6    07:01:40        1988
# 5      216      CA600 2017-05-10          7    17:05:57        1785
# 6      533      EA166 2017-05-10          3    07:50:18        2872
# 7       20      KB605 2017-05-10          6    16:47:25        3260
# 8      779      JC865 2017-05-10          1    05:55:17        2904
# 9      777      JC008 2017-05-10          8    15:02:51        2194
#
#    o_shape_seq  o_shape_lat  o_shape_lon  o_stop_id      ...        \
# 0      5444509   -25.451133   -49.252930      31749      ...
# 1      5510463   -25.432528   -49.272411      26355      ...
# 2      6136884   -25.427901   -49.263238      29914      ...
# 3      5305706   -25.452114   -49.223827      14404      ...
# 4      6403964   -25.550431   -49.265282      31256      ...
# 5      5950930   -25.466362   -49.279723      29165      ...
# 6      6247890   -25.516804   -49.230914      30037      ...
# 7      6011921   -25.447553   -49.225671      32704      ...
# 8      5602222   -25.459817   -49.319788      33567      ...
# 9      4299859   -25.435150   -49.273297      26149      ...
#
#    d_bus_code     d_date  d_tripNum  d_timestamp  d_shape_id d_shape_seq  \
# 0       BC032 2017-05-10          9     17:46:02        2789     5510463
# 1       BC289 2017-05-10         10     17:02:45        1743     5444509
# 2       LB602 2017-05-10          6     17:09:27        1719     5305706
# 3       BC312 2017-05-10          2     06:55:21        1891     6136884
# 4       CA600 2017-05-10          7     17:05:57        1785     5950930
# 5       GA124 2017-05-10          6     07:01:40        1988     6403964
# 6       KB605 2017-05-10          6     16:47:25        3260     6011921
# 7       EA166 2017-05-10          3     07:50:18        2872     6247890
# 8       JC008 2017-05-10          8     15:02:51        2194     4299859
# 9       JC865 2017-05-10          1     05:55:17        2904     5602222
#
#   d_shape_lat  d_shape_lon d_stop_id  d_boarding_id
# 0  -25.432528   -49.272411     26355              1
# 1  -25.451133   -49.252930     31749              0
# 2  -25.452114   -49.223827     14404              3
# 3  -25.427901   -49.263238     29914              2
# 4  -25.466362   -49.279723     29165              5
# 5  -25.550431   -49.265282     31256              4
# 6  -25.447553   -49.225671     32704              7
# 7  -25.516804   -49.230914     30037              6
# 8  -25.435150   -49.273297     26149              9
# 9  -25.459817   -49.319788     33567              8
#
# [10 rows x 25 columns]

# %%
print_df(origin_dest_matrix.select(['cardNum','o_route','o_bus_code','o_timestamp','o_stop_id','d_route','d_bus_code','d_timestamp','d_stop_id']).
        orderBy(['cardNum','o_timestamp',]), l=30)
# Out:
#     cardNum  o_route o_bus_code o_timestamp  o_stop_id  d_route d_bus_code  \
# 0    304127      175      BC289    17:02:45      31749      370      BC032
# 1    304127      370      BC032    17:46:02      26355      175      BC289
# 2    313992      372      BC312    06:55:21      29914       50      LB602
# 3    313992       50      LB602    17:09:27      14404      372      BC312
# 4    317896      542      GA124    07:01:40      31256      216      CA600
# 5    317896      216      CA600    17:05:57      29165      542      GA124
# 6    321530      533      EA166    07:50:18      30037       20      KB605
# 7    321530       20      KB605    16:47:25      32704      533      EA166
# 8    321916      779      JC865    05:55:17      33567      777      JC008
# 9    321916      777      JC008    15:02:51      26149      779      JC865
# 10   327178      175      BC018    12:46:13      27253      175      BC018
# 11   327178      175      BC018    16:54:37      28632      175      BC018
# 12   328918      643      GA164    11:55:17      32045      643      GA164
# 13   328918      643      GA164    11:55:20      32046      643      GA164
# 14   331911      370      BC032    08:08:40      30178      373      CC297
# 15   331911      373      CC297    14:54:45      26338      370      BC032
# 16   334290      614      GR403    07:16:10      29145      703      JC316
# 17   334290      703      JC316    17:05:51      35284      614      GR403
# 18   334492      777      LC027    08:28:45      32105      701      JC604
# 19   334492      701      JC604    17:40:55      32830      777      LC027
# 20   335836      703      JC314    08:43:42      35273      703      JC600
# 21   335836      703      JC600    18:13:14      26140      703      JC314
# 22   336277       40      HB606    05:54:04      33970      614      GR403
# 23   336277      614      GR403    17:16:19      29142       40      HB606
# 24   336471      639      GA122    07:15:05      37408      639      GA137
# 25   336471      639      GA137    13:39:46      37405      639      GA122
# 26   337143      777      LC027    07:15:27      26149       40      MB605
# 27   337143       40      MB605    18:06:09      33119      777      LC027
# 28   341853      180      HA310    07:25:15      28980      180      HA311
# 29   341853      180      HA311    16:20:26      26553      180      HA310
#
#    d_timestamp  d_stop_id
# 0     17:46:02      26355
# 1     17:02:45      31749
# 2     17:09:27      14404
# 3     06:55:21      29914
# 4     17:05:57      29165
# 5     07:01:40      31256
# 6     16:47:25      32704
# 7     07:50:18      30037
# 8     15:02:51      26149
# 9     05:55:17      33567
# 10    16:54:37      28632
# 11    12:46:13      27253
# 12    11:55:20      32046
# 13    11:55:17      32045
# 14    14:54:45      26338
# 15    08:08:40      30178
# 16    17:05:51      35284
# 17    07:16:10      29145
# 18    17:40:55      32830
# 19    08:28:45      32105
# 20    18:13:14      26140
# 21    08:43:42      35273
# 22    17:16:19      29142
# 23    05:54:04      33970
# 24    13:39:46      37405
# 25    07:15:05      37408
# 26    18:06:09      33119
# 27    07:15:27      26149
# 28    16:20:26      26553
# 29    07:25:15      28980

# %%
origin_dest_matrix.count()
# Out:
# 40480

# %%
origin_dest_matrix = origin_dest_matrix.withColumn('o_unixtimestamp',F.unix_timestamp(F.col('o_timestamp'), 'HH:mm:ss')) \
                                        .withColumn('d_unixtimestamp',F.unix_timestamp(F.col('d_timestamp'), 'HH:mm:ss'))

# %%
print_df(origin_dest_matrix)
# Out:
#    o_route o_bus_code     o_date  o_tripNum o_timestamp  o_shape_id  \
# 0      175      BC289 2017-05-10         10    17:02:45        1743
# 1      370      BC032 2017-05-10          9    17:46:02        2789
# 2      372      BC312 2017-05-10          2    06:55:21        1891
# 3       50      LB602 2017-05-10          6    17:09:27        1719
# 4      542      GA124 2017-05-10          6    07:01:40        1988
# 5      216      CA600 2017-05-10          7    17:05:57        1785
# 6      533      EA166 2017-05-10          3    07:50:18        2872
# 7       20      KB605 2017-05-10          6    16:47:25        3260
# 8      779      JC865 2017-05-10          1    05:55:17        2904
# 9      777      JC008 2017-05-10          8    15:02:51        2194
#
#    o_shape_seq  o_shape_lat  o_shape_lon  o_stop_id       ...         \
# 0      5444509   -25.451133   -49.252930      31749       ...
# 1      5510463   -25.432528   -49.272411      26355       ...
# 2      6136884   -25.427901   -49.263238      29914       ...
# 3      5305706   -25.452114   -49.223827      14404       ...
# 4      6403964   -25.550431   -49.265282      31256       ...
# 5      5950930   -25.466362   -49.279723      29165       ...
# 6      6247890   -25.516804   -49.230914      30037       ...
# 7      6011921   -25.447553   -49.225671      32704       ...
# 8      5602222   -25.459817   -49.319788      33567       ...
# 9      4299859   -25.435150   -49.273297      26149       ...
#
#    d_tripNum  d_timestamp  d_shape_id  d_shape_seq  d_shape_lat d_shape_lon  \
# 0          9     17:46:02        2789      5510463   -25.432528  -49.272411
# 1         10     17:02:45        1743      5444509   -25.451133  -49.252930
# 2          6     17:09:27        1719      5305706   -25.452114  -49.223827
# 3          2     06:55:21        1891      6136884   -25.427901  -49.263238
# 4          7     17:05:57        1785      5950930   -25.466362  -49.279723
# 5          6     07:01:40        1988      6403964   -25.550431  -49.265282
# 6          6     16:47:25        3260      6011921   -25.447553  -49.225671
# 7          3     07:50:18        2872      6247890   -25.516804  -49.230914
# 8          8     15:02:51        2194      4299859   -25.435150  -49.273297
# 9          1     05:55:17        2904      5602222   -25.459817  -49.319788
#
#   d_stop_id  d_boarding_id o_unixtimestamp  d_unixtimestamp
# 0     26355              1           72165            74762
# 1     31749              0           74762            72165
# 2     14404              3           35721            72567
# 3     29914              2           72567            35721
# 4     29165              5           36100            72357
# 5     31256              4           72357            36100
# 6     32704              7           39018            71245
# 7     30037              6           71245            39018
# 8     26149              9           32117            64971
# 9     33567              8           64971            32117
#
# [10 rows x 27 columns]

# %%
origin_dest_matrix = origin_dest_matrix.withColumn('leg_duration',
                                                   F.when(F.col('d_unixtimestamp') > F.col('o_unixtimestamp'),
                                                       ((F.col('d_unixtimestamp') - F.col('o_unixtimestamp'))/60.0)). \
                                                   otherwise(-1))

# %%
print_df(origin_dest_matrix.select(['cardNum','o_timestamp','o_unixtimestamp','d_timestamp','d_unixtimestamp','leg_duration']),l=30)
# Out:
#     cardNum o_timestamp  o_unixtimestamp d_timestamp  d_unixtimestamp  \
# 0    304127    17:02:45            72165    17:46:02            74762
# 1    304127    17:46:02            74762    17:02:45            72165
# 2    313992    06:55:21            35721    17:09:27            72567
# 3    313992    17:09:27            72567    06:55:21            35721
# 4    317896    07:01:40            36100    17:05:57            72357
# 5    317896    17:05:57            72357    07:01:40            36100
# 6    321530    07:50:18            39018    16:47:25            71245
# 7    321530    16:47:25            71245    07:50:18            39018
# 8    321916    05:55:17            32117    15:02:51            64971
# 9    321916    15:02:51            64971    05:55:17            32117
# 10   327178    12:46:13            56773    16:54:37            71677
# 11   327178    16:54:37            71677    12:46:13            56773
# 12   328918    11:55:17            53717    11:55:20            53720
# 13   328918    11:55:20            53720    11:55:17            53717
# 14   331911    08:08:40            40120    14:54:45            64485
# 15   331911    14:54:45            64485    08:08:40            40120
# 16   334290    07:16:10            36970    17:05:51            72351
# 17   334290    17:05:51            72351    07:16:10            36970
# 18   334492    08:28:45            41325    17:40:55            74455
# 19   334492    17:40:55            74455    08:28:45            41325
# 20   335836    08:43:42            42222    18:13:14            76394
# 21   335836    18:13:14            76394    08:43:42            42222
# 22   336277    05:54:04            32044    17:16:19            72979
# 23   336277    17:16:19            72979    05:54:04            32044
# 24   336471    07:15:05            36905    13:39:46            59986
# 25   336471    13:39:46            59986    07:15:05            36905
# 26   337143    07:15:27            36927    18:06:09            75969
# 27   337143    18:06:09            75969    07:15:27            36927
# 28   341853    07:25:15            37515    16:20:26            69626
# 29   341853    16:20:26            69626    07:25:15            37515
#
#     leg_duration
# 0      43.283333
# 1      -1.000000
# 2     614.100000
# 3      -1.000000
# 4     604.283333
# 5      -1.000000
# 6     537.116667
# 7      -1.000000
# 8     547.566667
# 9      -1.000000
# 10    248.400000
# 11     -1.000000
# 12      0.050000
# 13     -1.000000
# 14    406.083333
# 15     -1.000000
# 16    589.683333
# 17     -1.000000
# 18    552.166667
# 19     -1.000000
# 20    569.533333
# 21     -1.000000
# 22    682.250000
# 23     -1.000000
# 24    384.683333
# 25     -1.000000
# 26    650.700000
# 27     -1.000000
# 28    535.183333
# 29     -1.000000

# %%
print_df(origin_dest_matrix.filter('leg_duration < -1 or leg_duration > 15').describe(['leg_duration']))
# Out:
#   summary        leg_duration
# 0   count               17707
# 1    mean  375.82806328947106
# 2  stddev  220.45251361904775
# 3     min  15.033333333333333
# 4     max               963.9

# %%
origin_dest_matrix.filter('leg_duration > 0').approxQuantile("leg_duration", [0.5], 0)
# Out:
# [309.28333333333336]

# %%
origin_dest_matrix.write.csv(exp_data_folder_path + '/pre_od_matrix', header=True, mode='overwrite')
