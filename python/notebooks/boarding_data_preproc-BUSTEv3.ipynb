# %%
import pyspark
from pyspark import SparkContext
from pyspark.sql.window import Window
from pyspark.sql import functions as F
from pyspark.sql import types as T

import json
import numpy as np

# %%
def rename_columns(df, list_of_tuples):
    for (old_col, new_col) in list_of_tuples:
        df = df.withColumnRenamed(old_col, new_col)
    return df

def read_file(filepath, sqlContext):
    data_frame = sqlContext.read.csv(filepath, header=False,
                                     inferSchema=True,nullValue="-")
    while len(data_frame.columns) < 16:
        col_name = "_c" + str(len(data_frame.columns))
        data_frame = data_frame.withColumn(col_name, F.lit(None))

    data_frame = rename_columns(
        data_frame,
        [
            ("_c0", "route"),
            ("_c1", "tripNum"),
            ("_c2", "shapeId"),
            ("_c3", "shapeSequence"),
            ("_c4", "shapeLat"),
            ("_c5", "shapeLon"),
            ("_c6", "distanceTraveledShape"),
            ("_c7", "busCode"),
            ("_c8", "gpsPointId"),
            ("_c9", "gpsLat"),
            ("_c10", "gpsLon"),
            ("_c11", "distanceToShapePoint"),
            ("_c12", "timestamp"),
            ("_c13", "busStopId"),
            ("_c14", "problem"),
            ("_c15", "userBirthdate"),
            ("_c16", "cardTimestamp"),
            ("_c17", "lineName"),
            ("_c18", "cardNum"),
            ("_c19", "userGender"),
        ]
    )

    date = "-".join(filepath.split("/")[-2].split("_")[:3])

    data_frame = data_frame.withColumn("date", F.lit(date))
    data_frame = data_frame.withColumn("date", F.date_sub(F.col("date"),1))
    
    return data_frame

def print_df(df,l=10):
    return df.limit(l).toPandas()

# %% [markdown]
# ### Read BUSTE result Data

# %%
sc = SparkContext.getOrCreate()
sqlContext = pyspark.SQLContext(sc)

# %%
exp_data_folder_path = '/local/tarciso/masters/experiments/preliminary-exp/preliminary-exp-sample-data/'
user_boardings = read_file(exp_data_folder_path + '/bulma-output/2017_05_11_veiculos.csv/part-00000', sqlContext)

# %%
print_df(user_boardings)
# Out:
#   route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0   372        1     1891        6136720 -25.428213 -49.204401
# 1   372        1     1891        6136922 -25.432867 -49.270472
# 2   372        1     1891        6136922 -25.432867 -49.270472
# 3   372        1     1891        6136922 -25.432867 -49.270472
# 4   372        1     1890        6137134 -25.428043 -49.204411
# 5   372        1     1890        6137134 -25.428043 -49.204411
# 6   372        1     1890        6137169 -25.423290 -49.201495
# 7   372        1     1890        6137188 -25.419992 -49.200146
# 8   372        1     1890        6137197 -25.417748 -49.201223
# 9   372        1     1890        6137205 -25.415692 -49.202210
#
#    distanceTraveledShape busCode gpsPointId     gpsLat     ...      \
# 0               2604.580   CC170       None        NaN     ...
# 1              10381.698   CC170       None -25.432988     ...
# 2              10381.698   CC170       None -25.432988     ...
# 3              10381.698   CC170       None -25.432988     ...
# 4               7388.022   CC170       None -25.428011     ...
# 5               7388.022   CC170       None -25.428011     ...
# 6               8200.134   CC170       None -25.423383     ...
# 7               8748.949   CC170       None -25.419886     ...
# 8               9020.108   CC170       None -25.417635     ...
# 9               9268.598   CC170       None -25.415638     ...
#
#    distanceToShapePoint  timestamp busStopId     problem userBirthdate  \
# 0                   NaN   05:46:53     30817     BETWEEN      24/04/83
# 1             14.326287   06:05:23     26336  NO_PROBLEM      13/06/62
# 2             14.326287   06:05:23     26336  NO_PROBLEM      28/07/70
# 3             14.326287   06:05:23     26336  NO_PROBLEM      08/01/90
# 4              5.374579   06:23:08     30818  NO_PROBLEM      14/03/92
# 5              5.374579   06:23:08     30818  NO_PROBLEM      14/03/92
# 6             11.410669   06:25:25     30792  NO_PROBLEM      29/06/93
# 7             11.780608   06:26:54     30781  NO_PROBLEM      21/03/73
# 8             12.612804   06:27:45     30779  NO_PROBLEM      13/06/75
# 9              8.902769   06:28:27     30769  NO_PROBLEM      09/02/85
#
#   cardTimestamp lineName  cardNum  userGender        date
# 0      05:46:55   TARUMÃ  3395018          M   2017-05-10
# 1      06:07:55   TARUMÃ   459714          F   2017-05-10
# 2      06:07:00   TARUMÃ  2354665          F   2017-05-10
# 3      06:07:10   TARUMÃ  2694276          M   2017-05-10
# 4      06:23:23   TARUMÃ  1707734          F   2017-05-10
# 5      06:23:27   TARUMÃ  1707734          F   2017-05-10
# 6      06:26:16   TARUMÃ  3794429          M   2017-05-10
# 7      06:27:06   TARUMÃ  2525065          F   2017-05-10
# 8      06:28:25   TARUMÃ  3203155          F   2017-05-10
# 9      06:29:14   TARUMÃ  3768283          M   2017-05-10
#
# [10 rows x 21 columns]

# %%
user_boardings.printSchema()
# Out:
# root
#  |-- route: string (nullable = true)
#  |-- tripNum: integer (nullable = true)
#  |-- shapeId: integer (nullable = true)
#  |-- shapeSequence: integer (nullable = true)
#  |-- shapeLat: double (nullable = true)
#  |-- shapeLon: double (nullable = true)
#  |-- distanceTraveledShape: double (nullable = true)
#  |-- busCode: string (nullable = true)
#  |-- gpsPointId: string (nullable = true)
#  |-- gpsLat: double (nullable = true)
#  |-- gpsLon: double (nullable = true)
#  |-- distanceToShapePoint: double (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- busStopId: integer (nullable = true)
#  |-- problem: string (nullable = true)
#  |-- userBirthdate: string (nullable = true)
#  |-- cardTimestamp: string (nullable = true)
#  |-- lineName: string (nullable = true)
#  |-- cardNum: integer (nullable = true)
#  |-- userGender: string (nullable = true)
#  |-- date: date (nullable = true)

# %%
user_boardings.count()
# Out:
# 159889

# %%
user_boardings.select('cardNum').distinct().count()
# Out:
# 106885

# %%
#user_boardings.select(['route','busCode','tripNum','busStopId','sec_group','cardNum','cardTimestamp','gps_timestamp']).orderBy('cardNum','cardTimestamp').limit(20).toPandas()

# %% [markdown]
# ### Removing rows with missing data

# %%
filtered_boardings = user_boardings.na.drop(subset=["route","busCode","busStopId","timestamp","gpsLat","gpsLon","cardNum","cardTimestamp"])

# %%
print filtered_boardings.count()
print_df(filtered_boardings)
# Out:
# 117704
#   route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0   372        1     1891        6136922 -25.432867 -49.270472
# 1   372        1     1891        6136922 -25.432867 -49.270472
# 2   372        1     1891        6136922 -25.432867 -49.270472
# 3   372        1     1890        6137134 -25.428043 -49.204411
# 4   372        1     1890        6137134 -25.428043 -49.204411
# 5   372        1     1890        6137169 -25.423290 -49.201495
# 6   372        1     1890        6137188 -25.419992 -49.200146
# 7   372        1     1890        6137197 -25.417748 -49.201223
# 8   372        1     1890        6137205 -25.415692 -49.202210
# 9   372        1     1890        6137205 -25.415692 -49.202210
#
#    distanceTraveledShape busCode gpsPointId     gpsLat     ...      \
# 0              10381.698   CC170       None -25.432988     ...
# 1              10381.698   CC170       None -25.432988     ...
# 2              10381.698   CC170       None -25.432988     ...
# 3               7388.022   CC170       None -25.428011     ...
# 4               7388.022   CC170       None -25.428011     ...
# 5               8200.134   CC170       None -25.423383     ...
# 6               8748.949   CC170       None -25.419886     ...
# 7               9020.108   CC170       None -25.417635     ...
# 8               9268.598   CC170       None -25.415638     ...
# 9               9268.598   CC170       None -25.415638     ...
#
#    distanceToShapePoint  timestamp busStopId     problem userBirthdate  \
# 0             14.326287   06:05:23     26336  NO_PROBLEM      13/06/62
# 1             14.326287   06:05:23     26336  NO_PROBLEM      28/07/70
# 2             14.326287   06:05:23     26336  NO_PROBLEM      08/01/90
# 3              5.374579   06:23:08     30818  NO_PROBLEM      14/03/92
# 4              5.374579   06:23:08     30818  NO_PROBLEM      14/03/92
# 5             11.410669   06:25:25     30792  NO_PROBLEM      29/06/93
# 6             11.780608   06:26:54     30781  NO_PROBLEM      21/03/73
# 7             12.612804   06:27:45     30779  NO_PROBLEM      13/06/75
# 8              8.902769   06:28:27     30769  NO_PROBLEM      09/02/85
# 9              8.902769   06:28:27     30769  NO_PROBLEM      17/11/94
#
#   cardTimestamp lineName  cardNum  userGender        date
# 0      06:07:55   TARUMÃ   459714          F   2017-05-10
# 1      06:07:00   TARUMÃ  2354665          F   2017-05-10
# 2      06:07:10   TARUMÃ  2694276          M   2017-05-10
# 3      06:23:23   TARUMÃ  1707734          F   2017-05-10
# 4      06:23:27   TARUMÃ  1707734          F   2017-05-10
# 5      06:26:16   TARUMÃ  3794429          M   2017-05-10
# 6      06:27:06   TARUMÃ  2525065          F   2017-05-10
# 7      06:28:25   TARUMÃ  3203155          F   2017-05-10
# 8      06:29:14   TARUMÃ  3768283          M   2017-05-10
# 9      06:28:30   TARUMÃ  3599362          M   2017-05-10
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Removing duplicated passenger data

# %%
filtered_boardings = filtered_boardings.dropDuplicates(['cardNum','date','cardTimestamp'])

# %%
print filtered_boardings.count()
print_df(filtered_boardings)
# Out:
# 117702
#   route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0   547        4     1994        6165294 -25.541827 -49.264612
# 1   828        1     2941        4249004 -25.460141 -49.340811
# 2   777       11     2195        4299895 -25.442293 -49.269757
# 3   658        1     2115        6642358 -25.491613 -49.349015
# 4   628        2     2055        6035022 -25.544264 -49.315882
# 5   614        4     2030        5808518 -25.451123 -49.252929
# 6   561       15     2005        6405261 -25.462226 -49.262185
# 7   911       10     2260        4981458 -25.381588 -49.364092
# 8   684        2     2148        6636357 -25.592501 -49.332138
# 9   515        3     1956        6367399 -25.511734 -49.221422
#
#    distanceTraveledShape busCode gpsPointId     gpsLat     ...      \
# 0               4099.014   GA142       None -25.541680     ...
# 1               9660.000   LA001       None -25.460058     ...
# 2               1126.717   JC006       None -25.442241     ...
# 3               2871.251   JA027       None -25.491595     ...
# 4              11215.314   HA016       None -25.544026     ...
# 5               9972.134   GR405       None -25.451110     ...
# 6               3596.773   EC002       None -25.462290     ...
# 7               6371.622   MN400       None -25.381475     ...
# 8               1905.881   HR408       None -25.592538     ...
# 9               5028.205   EA164       None -25.511803     ...
#
#    distanceToShapePoint  timestamp busStopId     problem userBirthdate  \
# 0             31.689760   05:53:33     31271  NO_PROBLEM      22/04/63
# 1              9.355352   06:06:58     34257  NO_PROBLEM      28/05/63
# 2              7.728910   17:59:39     32903  NO_PROBLEM      03/02/93
# 3              3.681068   06:18:32     35720  NO_PROBLEM      28/07/71
# 4             40.477060   07:59:07     35163  NO_PROBLEM      06/03/89
# 5              4.154369   12:56:27     31749  NO_PROBLEM      20/09/66
# 6             11.532125   18:59:00     31986  NO_PROBLEM      24/04/57
# 7             22.177090   13:22:15     38953  NO_PROBLEM      18/10/83
# 8              5.097825   07:11:26     39373  NO_PROBLEM      06/08/73
# 9              8.828443   07:35:50     33516  NO_PROBLEM      24/10/84
#
#   cardTimestamp         lineName cardNum  userGender        date
# 0      05:54:23     V. SÃO PEDRO  431802          F   2017-05-10
# 1      06:07:54    C.COMP/C.RASO  433069          F   2017-05-10
# 2      18:00:33         V. VELHA  444810          F   2017-05-10
# 3      06:19:29     C.RASO/CAIUÁ  624028          M   2017-05-10
# 4      07:59:30       CARBOMAFRA  768474          F   2017-05-10
# 5      12:57:31   FAZENDINHA/PUC  829222          M   2017-05-10
# 6      18:59:08      GUILHERMINA  846408          F   2017-05-10
# 7      13:23:17  OP. CONTIGENCIA  883963          F   2017-05-10
# 8      07:11:39       RIO BONITO  927336          F   2017-05-10
# 9      07:36:14        IGUAPE II  952666          F   2017-05-10
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Removing single-trip users records

# %%
boarding_count = filtered_boardings.groupby('cardNum').count()

# %%
#Filtering only users with more than one ride per day
multiple_boardings = boarding_count.filter(F.col('count') > 1)

# %%
total_passengers = user_boardings.select('cardNum').distinct().count()
print "Total #Passengers:", total_passengers
# Out:
# Total #Passengers: 106885

# %%
passengers_mult_boardings = multiple_boardings.count()
prop_mult_boardings = 100*(passengers_mult_boardings)/total_passengers
print "Passengers with Multiple Boardings:", passengers_mult_boardings, "(", prop_mult_boardings, "%)" 
multiple_boardings.show()
# Out:
# Passengers with Multiple Boardings: 19895 ( 18 %)
# +-------+-----+
# |cardNum|count|
# +-------+-----+
# |3790541|    2|
# |3754400|    2|
# |2298968|    2|
# |3821560|    2|
# |3553903|    2|
# |3639748|    4|
# |3337195|    3|
# |2921321|    2|
# |1842089|    2|
# |1065595|    2|
# |3599737|    2|
# |3513400|    2|
# |3780899|    2|
# |2570449|    2|
# | 814837|    2|
# |2356476|    3|
# |2279865|    2|
# |1921487|    3|
# |3804401|    2|
# |2695352|    2|
# +-------+-----+
# only showing top 20 rows

# %%
multiple_boardings = multiple_boardings.select(F.col("cardNum").alias("cardNum1"),
                                                 F.col("count").alias("count1"))

# %%
clean_boardings = filtered_boardings.join(multiple_boardings, filtered_boardings.cardNum == multiple_boardings.cardNum1, 'leftsemi')

# %%
clean_boardings.count()
# Out:
# 43554

# %%
print_df(clean_boardings)
# Out:
#   route  tripNum  shapeId  shapeSequence   shapeLat   shapeLon  \
# 0   777       11     2195        4299895 -25.442293 -49.269757
# 1   658        1     2115        6642358 -25.491613 -49.349015
# 2   614        4     2030        5808518 -25.451123 -49.252929
# 3   684        2     2148        6636357 -25.592501 -49.332138
# 4   020        4     3259        6011355 -25.486591 -49.255923
# 5   040        1     1717        3366719 -25.432890 -49.352078
# 6   338        1     1871        5884653 -25.483813 -49.223565
# 7   860        9     2240        4494930 -25.447790 -49.308205
# 8   650        6     4166        6543310 -25.559689 -49.338679
# 9   653       10     3119        6040541 -25.507529 -49.334542
#
#    distanceTraveledShape busCode gpsPointId     gpsLat     ...      \
# 0               1126.717   JC006       None -25.442241     ...
# 1               2871.251   JA027       None -25.491595     ...
# 2               9972.134   GR405       None -25.451110     ...
# 3               1905.881   HR408       None -25.592538     ...
# 4              15948.485   BB613       None -25.486621     ...
# 5               5740.658   JB499       None -25.433115     ...
# 6               9008.924   EA001       None -25.483675     ...
# 7               4419.491   LC506       None -25.447751     ...
# 8               2885.735   HA031       None -25.559665     ...
# 9               1560.973   HA011       None -25.507698     ...
#
#    distanceToShapePoint  timestamp busStopId     problem userBirthdate  \
# 0              7.728910   17:59:39     32903  NO_PROBLEM      03/02/93
# 1              3.681068   06:18:32     35720  NO_PROBLEM      28/07/71
# 2              4.154369   12:56:27     31749  NO_PROBLEM      20/09/66
# 3              5.097825   07:11:26     39373  NO_PROBLEM      06/08/73
# 4             25.342314   12:51:26     32712  NO_PROBLEM      31/12/83
# 5             26.680422   06:41:13     33973  NO_PROBLEM      02/11/63
# 6             15.946461   06:22:02     32574  NO_PROBLEM      22/12/54
# 7             10.117585   18:04:40     30221  NO_PROBLEM      27/05/76
# 8              7.632886   11:23:40     36242  NO_PROBLEM      27/04/58
# 9             18.898020   12:59:43     33855  NO_PROBLEM      08/09/58
#
#   cardTimestamp              lineName  cardNum  userGender        date
# 0      18:00:33              V. VELHA   444810          F   2017-05-10
# 1      06:19:29          C.RASO/CAIUÁ   624028          M   2017-05-10
# 2      12:57:31        FAZENDINHA/PUC   829222          M   2017-05-10
# 3      07:11:39            RIO BONITO   927336          F   2017-05-10
# 4      12:51:53       INTERBAIRR II H   993266          M   2017-05-10
# 5      06:41:17       OP. CONTIGENCIA  1074995          F   2017-05-10
# 6      06:22:13      CENTENÁRIO/HAUER  1366300          F   2017-05-10
# 7      18:05:34             V. SANDRA  1393454          M   2017-05-10
# 8      11:24:41  STA.RITA/PINHEIRINHO  1432524          M   2017-05-10
# 9      05:19:17                SABARÁ  1536386          F   2017-05-10
#
# [10 rows x 21 columns]

# %%
clean_boardings.write.csv(path=exp_data_folder_path+'/clean_boardings',header=True, mode='overwrite')
